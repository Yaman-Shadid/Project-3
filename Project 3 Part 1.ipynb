# %% [markdown]
# # Project 3

# %% [markdown]
# ## Imports and integration

# %%
import pandas as pd
import numpy as np

# %%
import os
os.makedirs('Data/',exist_ok=True) # Confirm folder created
os.listdir("Data/")
# Out:
# ['name.basics.tsv.gz',
#  'title-akas-us-only.csv',
#  'title.akas.tsv.gz',
#  'title.basics.tsv.gz',
#  'title.crew.tsv.gz',
#  'title.episode.tsv.gz',
#  'title.principals.tsv.gz',
#  'title.ratings.tsv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz']

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1997
# 1  tt0000002            5.8       269
# 2  tt0000003            6.5      1886
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2671

# %% [markdown]
# ## Basics

# %%
basics = basics.replace({'\\N':np.nan})
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# 1. Eliminate movies that are null for 'runtimeMinutes'
basics = basics[basics['runtimeMinutes'].notnull()]

# %%
# 2. Eliminate movies that are null for 'genres'
basics = basics[basics['genres'].notnull()]

# %%
# 3. Keep only titleType==Movie
basics = basics[basics['titleType'] == 'movie']

# %%
# 4. Convert the startYear column to float data type
basics['startYear'] = basics['startYear'].astype(float)

# %%
# 5. Filter the dataframe using startYear. Keep years between 2000-2021
basics = basics[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2021)]

# %%
# 6. Eliminate movies that include "Documentary" in the genre
basics = basics[~basics['genres'].str.contains('Documentary')]

# %%
# 7. Keep only US movies
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34800       True
# 61111       True
# 67485       True
# 67663       True
# 80548       True
#             ...
# 10215129    True
# 10215168    True
# 10215213    True
# 10215297    True
# 10215387    True
# Name: tconst, Length: 139181, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#              tconst titleType  \
# 34800     tt0035423     movie
# 61111     tt0062336     movie
# 67485     tt0068865     movie
# 67663     tt0069049     movie
# 80548     tt0082328     movie
# ...             ...       ...
# 10215129  tt9916190     movie
# 10215168  tt9916270     movie
# 10215213  tt9916362     movie
# 10215297  tt9916538     movie
# 10215387  tt9916730     movie
#
#                                                primaryTitle  \
# 34800                                        Kate & Leopold
# 61111     The Tango of the Widower and Its Distorting Mi...
# 67485                                   Lives of Performers
# 67663                            The Other Side of the Wind
# 80548                                    Embodiment of Evil
# ...                                                     ...
# 10215129                                          Safeguard
# 10215168                           Il talento del calabrone
# 10215213                                              Coven
# 10215297                                Kuambil Lagi Hatiku
# 10215387                                             6 Gunn
#
#                                       originalTitle isAdult  startYear  \
# 34800                                Kate & Leopold       0     2001.0
# 61111     El tango del viudo y su espejo deformante       0     2020.0
# 67485                           Lives of Performers       0     2016.0
# 67663                    The Other Side of the Wind       0     2018.0
# 80548                         Encarnação do Demônio       0     2008.0
# ...                                             ...     ...        ...
# 10215129                                  Safeguard       0     2020.0
# 10215168                   Il talento del calabrone       0     2020.0
# 10215213                                   Akelarre       0     2020.0
# 10215297                        Kuambil Lagi Hatiku       0     2019.0
# 10215387                                     6 Gunn       0     2017.0
#
#          endYear runtimeMinutes                     genres
# 34800        NaN            118     Comedy,Fantasy,Romance
# 61111        NaN             70                      Drama
# 67485        NaN             90                      Drama
# 67663        NaN            122                      Drama
# 80548        NaN             94                     Horror
# ...          ...            ...                        ...
# 10215129     NaN             95  Action,Adventure,Thriller
# 10215168     NaN             84                   Thriller
# 10215213     NaN             92              Drama,History
# 10215297     NaN            123                      Drama
# 10215387     NaN            116                      Drama
#
# [138501 rows x 9 columns]

# %% [markdown]
# # AKAS

# %%
akas = akas.replace({'\\N':np.nan})
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
# Keep only US movies
akas = akas[akas['region'] == 'US']

# %% [markdown]
# # Ratings

# %%
ratings = ratings.replace({'\\N':np.nan})
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1997
# 1  tt0000002            5.8       269
# 2  tt0000003            6.5      1886
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2671

# %%
# Filter ratings based on akas
keepers_ratings = ratings['tconst'].isin(akas['titleId'])

# %%
ratings = ratings[keepers_ratings]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1997
# 1        tt0000002            5.8       269
# 4        tt0000005            6.2      2671
# 5        tt0000006            5.0       182
# 6        tt0000007            5.4       836
# ...            ...            ...       ...
# 1356044  tt9916200            8.1       237
# 1356045  tt9916204            8.2       272
# 1356052  tt9916348            8.3        18
# 1356053  tt9916362            6.4      5555
# 1356058  tt9916428            3.5        17
#
# [510691 rows x 3 columns]

# %% [markdown]
# ## Saving Compressed .csv.gz Files

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0082328     movie                                 Embodiment of Evil
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                      Encarnação do Demônio        0     2008.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2              90                   Drama
# 3             122                   Drama
# 4              94                  Horror

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1997
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2671
# 3  tt0000006            5.0       182
# 4  tt0000007            5.4       836
